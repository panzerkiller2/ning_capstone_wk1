# %%
# This notebook is for coursera capstone project


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from bs4 import BeautifulSoup
import urllib.request

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page,"lxml")
#print(soup.prettify())

# %%
#tb.findAll('tr')[55].findAll('td')
soup.title.string
# Out:
# 'List of postal codes of Canada: M - Wikipedia'

# %%
tb = soup.find("table", class_ = "wikitable sortable")
A=[]
B=[]
C=[]

for row in tb.findAll('tr'):
    cells=row.findAll('td')
    if len(cells)==3:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

# %%
import pandas as pd
df=pd.DataFrame(A,columns=['Postcode'])
df['Borough']=B
df['Neighborhood']=C

# %%
df.shape
# Out:
# (288, 3)

# %%
geo = pd.read_csv('../input/geospatial-coordinates/Geospatial_Coordinates.csv')

geo.shape
# Out:
# (103, 3)

# %%
geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df
# Out:
#     Postcode                        ...                                                               Neighborhood
# 0        M1A                        ...                                                              Not assigned
#
# 1        M2A                        ...                                                              Not assigned
#
# 2        M3A                        ...                                                                  Parkwoods
# 3        M4A                        ...                                                           Victoria Village
# 4        M5A                        ...                                                               Harbourfront
# 5        M5A                        ...                                                                Regent Park
# 6        M6A                        ...                                                           Lawrence Heights
# ...

# %%
df2 = df.merge(geo, left_on='Postcode', right_on='Postal Code',suffixes=('_1', '_2'))

# %%
geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df2.head()
# Out:
#   Postcode           Borough    ...       Latitude  Longitude
# 0      M3A        North York    ...      43.753259 -79.329656
# 1      M4A        North York    ...      43.725882 -79.315572
# 2      M5A  Downtown Toronto    ...      43.654260 -79.360636
# 3      M5A  Downtown Toronto    ...      43.654260 -79.360636
# 4      M6A        North York    ...      43.718518 -79.464763
#
# [5 rows x 6 columns]

# %%
df2.shape
# Out:
# (211, 6)

# %%
df2.drop(columns=['Postal Code'])
# Out:
#     Postcode           Borough    ...       Latitude  Longitude
# 0        M3A        North York    ...      43.753259 -79.329656
# 1        M4A        North York    ...      43.725882 -79.315572
# 2        M5A  Downtown Toronto    ...      43.654260 -79.360636
# 3        M5A  Downtown Toronto    ...      43.654260 -79.360636
# 4        M6A        North York    ...      43.718518 -79.464763
# 5        M6A        North York    ...      43.718518 -79.464763
# 6        M7A      Queen's Park    ...      43.662301 -79.389494
# 7        M9A         Etobicoke    ...      43.667856 -79.532242
# 8        M1B       Scarborough    ...      43.806686 -79.194353
# 9        M1B       Scarborough    ...      43.806686 -79.194353
# 10       M3B        North York    ...      43.745906 -79.352188
# 11       M4B         East York    ...      43.706397 -79.309937
# 12       M4B         East York    ...      43.706397 -79.309937
# 13       M5B  Downtown Toronto    ...      43.657162 -79.378937
# ...
